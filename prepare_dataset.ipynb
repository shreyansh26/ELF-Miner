# %%
import pandas as pd
import numpy as np

# %%
df_benign = pd.read_csv('re_benign_final.csv')
df_benign.head()
# Out:
#            Name                                   Identification  \
# 0          1425  7f 45 4c 46 02 01 01 00 00 00 00 00 00 00 00 00
# 1      hostname  7f 45 4c 46 02 01 01 00 00 00 00 00 00 00 00 00
# 2      nautilus  7f 45 4c 46 02 01 01 00 00 00 00 00 00 00 00 00
# 3  cups-browsed  7f 45 4c 46 02 01 01 00 00 00 00 00 00 00 00 00
# 4       sulogin  7f 45 4c 46 02 01 01 00 00 00 00 00 00 00 00 00
#
#                      MachineType  ELFVersion EntryPointAddress  \
# 0  Advanced Micro Devices X86-64           1            400430
# 1  Advanced Micro Devices X86-64           1            401480
# 2  Advanced Micro Devices X86-64           1            42bad0
# 3  Advanced Micro Devices X86-64           1            407280
# 4  Advanced Micro Devices X86-64           1            4042a0
#
#    ProgramHeaderOffset  SectionHeaderOffset  Flags  HeaderSize  \
# 0                   64                 6664      0          64
# 1                   64                12944      0          64
# ...

# %%
df_benign['label'] = 'B'

# %%
df_benign.head()
# Out:
#            Name                                   Identification  \
# 0          1425  7f 45 4c 46 02 01 01 00 00 00 00 00 00 00 00 00
# 1      hostname  7f 45 4c 46 02 01 01 00 00 00 00 00 00 00 00 00
# 2      nautilus  7f 45 4c 46 02 01 01 00 00 00 00 00 00 00 00 00
# 3  cups-browsed  7f 45 4c 46 02 01 01 00 00 00 00 00 00 00 00 00
# 4       sulogin  7f 45 4c 46 02 01 01 00 00 00 00 00 00 00 00 00
#
#                      MachineType  ELFVersion EntryPointAddress  \
# 0  Advanced Micro Devices X86-64           1            400430
# 1  Advanced Micro Devices X86-64           1            401480
# 2  Advanced Micro Devices X86-64           1            42bad0
# 3  Advanced Micro Devices X86-64           1            407280
# 4  Advanced Micro Devices X86-64           1            4042a0
#
#    ProgramHeaderOffset  SectionHeaderOffset  Flags  HeaderSize  \
# 0                   64                 6664      0          64
# 1                   64                12944      0          64
# ...

# %%
df_benign.to_csv('benign.csv', index=False)

# %%
df_malware = pd.read_csv('re_malware_final.csv')
df_malware.head()
# Out:
# /usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (7,42,43,136) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                                                 Name  \
# 0  800f8b125345784d532b29465b5c57d05287235d353553...
# 1  281491500be26d87280e9bfc201799dee35d00a70830dc...
# 2  99c3f6308185566bc036989b51f1bffb8c3b4a88106f41...
# 3  f45833fc8629ed7a36294ad3ea5d97017d35af44281215...
# 4  877e20c0238e77912285a59505f1c2cb60ad12807ce488...
#
#                                     Identification  MachineType  ELFVersion  \
# 0  7f 45 4c 46 01 01 01 00 00 00 00 00 00 00 00 00  Intel 80386           1
# 1  7f 45 4c 46 01 01 01 00 00 00 00 00 00 00 00 00  Intel 80386           1
# 2  7f 45 4c 46 01 01 01 00 00 00 00 00 00 00 00 00  Intel 80386           1
# 3  7f 45 4c 46 01 01 01 00 00 00 00 00 00 00 00 00  Intel 80386           1
# ...

# %%
df_malware['label'] = 'M'

# %%
df_malware.head()
# Out:
#                                                 Name  \
# 0  800f8b125345784d532b29465b5c57d05287235d353553...
# 1  281491500be26d87280e9bfc201799dee35d00a70830dc...
# 2  99c3f6308185566bc036989b51f1bffb8c3b4a88106f41...
# 3  f45833fc8629ed7a36294ad3ea5d97017d35af44281215...
# 4  877e20c0238e77912285a59505f1c2cb60ad12807ce488...
#
#                                     Identification  MachineType  ELFVersion  \
# 0  7f 45 4c 46 01 01 01 00 00 00 00 00 00 00 00 00  Intel 80386           1
# 1  7f 45 4c 46 01 01 01 00 00 00 00 00 00 00 00 00  Intel 80386           1
# 2  7f 45 4c 46 01 01 01 00 00 00 00 00 00 00 00 00  Intel 80386           1
# 3  7f 45 4c 46 01 01 01 00 00 00 00 00 00 00 00 00  Intel 80386           1
# 4  7f 45 4c 46 01 01 01 00 00 00 00 00 00 00 00 00  Intel 80386           1
#
#   EntryPointAddress  ProgramHeaderOffset  SectionHeaderOffset Flags  \
# 0           8049130                   52                39524     0
# ...

# %%
df_malware.to_csv('malware.csv', index=False)

# %% [markdown]
# # Prepare dataset

# %%
benign = pd.read_csv('benign.csv')
malware = pd.read_csv('malware.csv')

# %%
print(benign.shape, malware.shape)
# Out:
# ((2180, 343), (6945, 343))

# %%
dataset_initial = pd.concat([benign, malware], axis=0)

# %%
dataset_initial.shape
# Out:
# (9125, 343)

# %%
dataset_shuffled = dataset_initial.sample(frac=1).reset_index(drop=True)
dataset_shuffled.shape
# Out:
# (9125, 343)

# %%
dataset_initial.head()
# Out:
#            Name                                   Identification  \
# 0          1425  7f 45 4c 46 02 01 01 00 00 00 00 00 00 00 00 00
# 1      hostname  7f 45 4c 46 02 01 01 00 00 00 00 00 00 00 00 00
# 2      nautilus  7f 45 4c 46 02 01 01 00 00 00 00 00 00 00 00 00
# 3  cups-browsed  7f 45 4c 46 02 01 01 00 00 00 00 00 00 00 00 00
# 4       sulogin  7f 45 4c 46 02 01 01 00 00 00 00 00 00 00 00 00
#
#                      MachineType  ELFVersion EntryPointAddress  \
# 0  Advanced Micro Devices X86-64           1            400430
# 1  Advanced Micro Devices X86-64           1            401480
# 2  Advanced Micro Devices X86-64           1            42bad0
# 3  Advanced Micro Devices X86-64           1            407280
# 4  Advanced Micro Devices X86-64           1            4042a0
#
#    ProgramHeaderOffset  SectionHeaderOffset Flags  HeaderSize  \
# 0                   64                 6664     0          64
# 1                   64                12944     0          64
# ...

# %%
dataset_shuffled.head()
# Out:
#                                                 Name  \
# 0  42d7e2ac43d89f40d5e0debf3a4294fce4ee75ffae2db9...
# 1                                            pstopnm
# 2  2a5c4b8a739b4c1c85f4866abb02a4699112d09d60ea41...
# 3  7fbce893dc6a51456fadcf86179ac0eff9026eb17b7f04...
# 4  971062ea5bcbfd9998ff22acebc1a361a151fb1fb8d4e6...
#
#                                     Identification  \
# 0  7f 45 4c 46 01 01 01 00 00 00 00 00 00 00 00 00
# 1  7f 45 4c 46 02 01 01 00 00 00 00 00 00 00 00 00
# 2  7f 45 4c 46 01 01 01 00 00 00 00 00 00 00 00 00
# 3  7f 45 4c 46 02 01 01 00 00 00 00 00 00 00 00 00
# 4  7f 45 4c 46 01 01 01 00 00 00 00 00 00 00 00 00
#
#                      MachineType  ELFVersion EntryPointAddress  \
# 0                    Intel 80386           1           804e2a1
# 1  Advanced Micro Devices X86-64           1            401f70
# 2                    Intel 80386           1           8048164
# 3  Advanced Micro Devices X86-64           1            400503
# ...

# %%
train_df = dataset_shuffled.iloc[:6388, :]
test_df = dataset_shuffled.iloc[6388:, :]

# %%
print(train_df.shape, test_df.shape)
# Out:
# ((6388, 343), (2737, 343))

# %%
train_df['label'].value_counts()
# Out:
# M    4910
# B    1478
# Name: label, dtype: int64

# %%
test_df['label'].value_counts()
# Out:
# M    2035
# B     702
# Name: label, dtype: int64

# %%
train_df.to_csv('train.csv', index=False)
test_df.to_csv('test.csv', index=False)
